# %%
from dotenv import load_dotenv
import os
import pandas as pd
from pyoso import Client

load_dotenv()
OSO_API_KEY = os.environ['OSO_API_KEY']
client = Client(api_key=OSO_API_KEY)

# %% [markdown]
# ## Github Metrics for Stylus Sprint Projects
# Query key GitHub activity metrics from 2024-2025 for Stylus Sprint projects, providing insights into project development velocity and community engagement.

# %%
query = """
    SELECT  p.display_name as Name,
            m.metric_name as Metric,
            ts.sample_date as Date,
            ts.amount as Value
    FROM metrics_v0 m
    JOIN timeseries_metrics_by_project_v0 ts
    on m.metric_id = ts.metric_id
    JOIN projects_v1 p
    on p.project_id = ts.project_id
    where metric_name like 'GITHUB_%'
    and YEAR(ts.sample_date) in (2024, 2025)
    and p.project_name IN (
        '9lives-fluidity-money',
        'angel',
        'arbos-foundry-bernard-wagner',
        'cobuilders-xyz',
        'codetracer-metacraft-labs',
        'ember-shahankhatch',
        'enclave-gnosisguild',
        'fairblock',
        'fiet-protocol-usherlabs',
        'nuffle-labs',
        'opensource-observer',
        'passportxyz',
        'pyth-network',
        'rather_labs',
        'redstone-finance',
        'remix-arbitrum-welldonestudio',
        'runtimeverification',
        'solang-hyperledger-solang',
        'stylusport-teamscanworks',
        'sylow-warlock-labs',
        'syndicateprotocol',
        'third-web',
        'trailofbits',
        'wakeuplabs',
        'walnuthq')
"""

df = client.to_pandas(query)
df['Date'] = pd.to_datetime(df['Date'])

df.to_csv('stylus_github_metrics.csv', index=False)
df
# Out:
#                                  Name                      Metric       Date  \
# 0      Trail of Bits Security Reviews       GITHUB_comments_daily 2024-01-08
# 1                        Pyth Network       GITHUB_comments_daily 2024-01-08
# 2                Open Source Observer       GITHUB_comments_daily 2024-01-08
# 3                            thirdweb       GITHUB_comments_daily 2024-01-08
# 4                Runtime Verification       GITHUB_comments_daily 2024-01-08
# ...                               ...                         ...        ...
# 49779            Runtime Verification  GITHUB_opened_issues_daily 2024-05-30
# 49780                        thirdweb  GITHUB_opened_issues_daily 2024-05-30
# 49781            Open Source Observer  GITHUB_opened_issues_daily 2024-05-30
# 49782            Open Source Observer  GITHUB_closed_issues_daily 2024-05-30
# 49783                        thirdweb  GITHUB_closed_issues_daily 2024-05-30
#
#        Value
# 0        3.0
# 1       19.0
# 2        7.0
# 3       30.0
# 4       18.0
# ...      ...
# 49779    3.0
# 49780    1.0
# 49781    3.0
# 49782    2.0
# 49783    2.0
#
# [49784 rows x 4 columns]

# %% [markdown]
# ## Mapping the Stylus SDK Ecosystem
#
# This analysis tracks the network of dependencies for projects using the Stylus SDK for Rust. By examining package relationships and ownership patterns, we can understand how the Stylus ecosystem is growing and evolving.

# %%
query = """
WITH seed_repos AS (
  -- First get all repos that depend on stylus-sdk-rs packages
  SELECT DISTINCT 
    sboms.from_artifact_namespace,
    sboms.from_artifact_name
  FROM sboms_v0 sboms
  JOIN package_owners_v0 package_owners
    ON sboms.to_package_artifact_name = package_owners.package_artifact_name
    AND sboms.to_package_artifact_source = package_owners.package_artifact_source
  WHERE package_owners.package_owner_artifact_namespace = 'offchainlabs'
    AND package_owners.package_owner_artifact_name = 'stylus-sdk-rs'
)
SELECT DISTINCT
  sboms.from_artifact_namespace as seed_repo_owner,
  sboms.from_artifact_name as seed_repo_name,
  sboms.to_package_artifact_name as package_name,
  package_owners.package_owner_artifact_namespace as package_repo_owner,
  package_owners.package_owner_artifact_name as package_repo_name,
  sboms.to_package_artifact_source as package_source
FROM sboms_v0 sboms
JOIN package_owners_v0 package_owners
  ON sboms.to_package_artifact_name = package_owners.package_artifact_name
  AND sboms.to_package_artifact_source = package_owners.package_artifact_source
JOIN seed_repos
  ON sboms.from_artifact_namespace = seed_repos.from_artifact_namespace
  AND sboms.from_artifact_name = seed_repos.from_artifact_name
WHERE package_owners.package_owner_artifact_namespace IS NOT NULL
"""
df = client.to_pandas(query)

df.to_csv('stylus-sdk-rs-dependencies.csv', index=False)

df
# Out:
#       seed_repo_owner                     seed_repo_name  \
# 0            theblokc           arbdevbootcamp-reference
# 1            teeeeeo9                 basket-swap-stylus
# 2            seabrick                 seabrick-contracts
# 3            dsrvlabs   arbiturm-stylus-solidity-compare
# 4        offchainlabs  stylus-quickstart-vending-machine
# ...               ...                                ...
# 14525    offchainlabs                      stylus-erc721
# 14526        theblokc           arbdevbootcamp-reference
# 14527    offchainlabs                      stylus-erc721
# 14528    offchainlabs                      stylus-erc721
# 14529    offchainlabs                      stylus-erc721
#
#                  package_name package_repo_owner package_repo_name  \
# 0      update-browserslist-db       browserslist         update-db
# 1                strum_macros        peternator7             strum
# 2                strum_macros        peternator7             strum
# 3                strum_macros        peternator7             strum
# 4                strum_macros        peternator7             strum
# ...                       ...                ...               ...
# 14525            string-width       sindresorhus      string-width
# 14526            string-width       sindresorhus      string-width
# 14527                 mock-fs            tschaub           mock-fs
# 14528        eth-ens-namehash          danfinlay  eth-ens-namehash
# 14529      @truffle/abi-utils       trufflesuite           truffle
#
#       package_source
# 0                NPM
# 1               RUST
# 2               RUST
# 3               RUST
# 4               RUST
# ...              ...
# 14525            NPM
# 14526            NPM
# 14527            NPM
# 14528            NPM
# 14529            NPM
#
# [14530 rows x 6 columns]

# %%
query = """
    SELECT  *
    FROM projects_by_collection_v1
    where collection_name = 'arb-stylus'
"""

df = client.to_pandas(query)
df
# Out:
#                                       project_id project_source  \
# 0   VW4ai7Oe7BPLYGMIxn2WDhjqFHxkgiEeNqtfal8rsDI=  OSS_DIRECTORY
# 1   /pssu0aR5Cdtw3rKZm3GPxIcX4lIZQ/4vNcr5JHEntQ=  OSS_DIRECTORY
# 2   8qT+MBh7I3vFIRAuXywGE6IDmrJ3kVZU4Ij8oSTnBDw=  OSS_DIRECTORY
# 3   RWuM31//tVs8AiRYjWQ6Q+ZGokQxcvFcCjxAsU+/NFc=  OSS_DIRECTORY
# 4   Dmd+SVhJ+mwyF92e/YB4uqPGcFiVLEsd5/rpI3Yqdlg=  OSS_DIRECTORY
# 5   c4jhBNaF9r5TQikW0NcdqLWisfm+nj19cLmF14hdqxE=  OSS_DIRECTORY
# 6   aEbUj/g//mRNKuO95T3vNUPtR0XELER317FEV1AyRQE=  OSS_DIRECTORY
# 7   7qBBhoNmu96/1jl6mMV0OmT7SQwHQ770ttBJyGc/yVY=  OSS_DIRECTORY
# 8   bJGGrZkVMcsuugz42MngMfJkLw0g3FE+m0V4NwjpQb8=  OSS_DIRECTORY
# 9   Afpw4lZt7zu3zMODQd0W3l3d9I7plIqyyHYmmuaF49Y=  OSS_DIRECTORY
# 10  UuWbpo5bpL5QsYvlukUWNm2uE8HFjxQxzCM0e+HMZfk=  OSS_DIRECTORY
# 11  5uZFQH9IOekf6/GyA0E9dfbJwIRCmUIbU7Leycl0s4Y=  OSS_DIRECTORY
# 12  7CbZT+Alw8Biv6iCgptzNOvAwOUFg3FBfHQ/Msuw4no=  OSS_DIRECTORY
# 13  xZZJ9hSu36WWGYyC6HM1+eat+d26oa+wpxGL8NMAIPA=  OSS_DIRECTORY
# 14  B7GkZ8pVhUd8PqLXOH5d/4Ui0XxPUk8Xmz5Dffp0h+k=  OSS_DIRECTORY
# 15  Hto4en/hR3KSMnBhfEr5jNfA956L1K7E2zyAnNVJ0/s=  OSS_DIRECTORY
# 16  Lz2IraizLQ8v5R+MB/DOhPyJnrwhB/KbpjsMUgmxN/o=  OSS_DIRECTORY
# 17  y660pHREqKARqiNLE0IPAnZ0J+clq4vYw/ki5F1D7A0=  OSS_DIRECTORY
# 18  bOoOeeFN/RnEjpyWSG8deYRlWhA+FobZ3bfNRD4oBhg=  OSS_DIRECTORY
# 19  3MO3nbyyakjGIE5J9Ux7KllLnGECutCiW2zqA6yZ49g=  OSS_DIRECTORY
# 20  jQ7nIMyduXrt4003gZDif92/RsY/gFlVQ9FJ8iWhpi4=  OSS_DIRECTORY
# 21  SrAW7CxbX2q6KzPf1xXwJsc5IQZqIkDDOkAx3/nTS0M=  OSS_DIRECTORY
# 22  M9QFoh4repQ2Tf43GBModC04uxjxTOpE54sIRZ7P+1g=  OSS_DIRECTORY
# 23  KB/syI+Jb/V6wpaa+aUYeoJnZ/xpMRkjUcogku8YQ4s=  OSS_DIRECTORY
# 24  CS6nF2QQt8KkkzZenRApwJcT+xGaKpoLij7Oe1AcwJI=  OSS_DIRECTORY
#
#    project_namespace                   project_name  \
# 0                oso          9lives-fluidity-money
# 1                oso                          angel
# 2                oso   arbos-foundry-bernard-wagner
# 3                oso                 cobuilders-xyz
# 4                oso      codetracer-metacraft-labs
# 5                oso             ember-shahankhatch
# 6                oso            enclave-gnosisguild
# 7                oso                      fairblock
# 8                oso        fiet-protocol-usherlabs
# 9                oso                    nuffle-labs
# 10               oso            opensource-observer
# 11               oso                    passportxyz
# 12               oso                   pyth-network
# 13               oso                    rather_labs
# 14               oso               redstone-finance
# 15               oso  remix-arbitrum-welldonestudio
# 16               oso            runtimeverification
# 17               oso      solang-hyperledger-solang
# 18               oso       stylusport-teamscanworks
# 19               oso             sylow-warlock-labs
# 20               oso              syndicateprotocol
# 21               oso                      third-web
# 22               oso                    trailofbits
# 23               oso                     wakeuplabs
# 24               oso                       walnuthq
#
#                                    collection_id collection_source  \
# 0   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 1   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 2   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 3   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 4   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 5   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 6   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 7   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 8   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 9   fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 10  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 11  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 12  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 13  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 14  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 15  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 16  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 17  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 18  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 19  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 20  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 21  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 22  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 23  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
# 24  fsMsF4dD+zjhtZ0KA3NAUGZ6AboXhGR6fTf+72nceIc=     OSS_DIRECTORY
#
#    collection_namespace collection_name
# 0                   oso      arb-stylus
# 1                   oso      arb-stylus
# 2                   oso      arb-stylus
# 3                   oso      arb-stylus
# 4                   oso      arb-stylus
# 5                   oso      arb-stylus
# 6                   oso      arb-stylus
# 7                   oso      arb-stylus
# 8                   oso      arb-stylus
# 9                   oso      arb-stylus
# 10                  oso      arb-stylus
# 11                  oso      arb-stylus
# 12                  oso      arb-stylus
# 13                  oso      arb-stylus
# 14                  oso      arb-stylus
# 15                  oso      arb-stylus
# 16                  oso      arb-stylus
# 17                  oso      arb-stylus
# 18                  oso      arb-stylus
# 19                  oso      arb-stylus
# 20                  oso      arb-stylus
# 21                  oso      arb-stylus
# 22                  oso      arb-stylus
# 23                  oso      arb-stylus
# 24                  oso      arb-stylus

# %%
query = """
    WITH arb_projects AS (
        SELECT distinct project_id
        FROM int_artifacts_by_project_in_ossd
        WHERE artifact_source = 'ARBITRUM_ONE'
        AND artifact_type IN ('CONTRACT', 'FACTORY', 'DEPLOYER')
    )
    SELECT  p.display_name as Name,
            m.metric_name as Metric,
            ts.sample_date as Date,
            ts.amount as Value
    FROM metrics_v0 m
    JOIN timeseries_metrics_by_project_v0 ts
    on m.metric_id = ts.metric_id
    JOIN projects_v1 p
    on p.project_id = ts.project_id
    JOIN arb_projects a
    on p.project_id = a.project_id
    where metric_name = 'GITHUB_active_developers_monthly'
    and YEAR(ts.sample_date) in (2024, 2025)
"""

df = client.to_pandas(query)
df.to_csv('arb_projects_active_dev_monthly.csv', index=False)
df
# Out:
#                    Name                            Metric        Date  Value
# 0       Algebra Finance  GITHUB_active_developers_monthly  2024-04-01      3
# 1             Furucombo  GITHUB_active_developers_monthly  2024-04-01      4
# 2     powerpool-finance  GITHUB_active_developers_monthly  2024-04-01      3
# 3          Frax Finance  GITHUB_active_developers_monthly  2024-04-01      3
# 4              LlamaPay  GITHUB_active_developers_monthly  2024-04-01      2
# ...                 ...                               ...         ...    ...
# 4191         Superfluid  GITHUB_active_developers_monthly  2025-02-01      7
# 4192            Sablier  GITHUB_active_developers_monthly  2025-02-01      7
# 4193                GMX  GITHUB_active_developers_monthly  2025-02-01      6
# 4194          KyberSwap  GITHUB_active_developers_monthly  2025-02-01     18
# 4195         Overnight+  GITHUB_active_developers_monthly  2025-02-01      3
#
# [4196 rows x 4 columns]

# %%
query = """
  WITH dep_projects AS (
  SELECT distinct sboms.from_project_id
  FROM sboms_v0 sboms
  JOIN package_owners_v0 package_owners
    ON sboms.to_package_artifact_name = package_owners.package_artifact_name
    AND sboms.to_package_artifact_source = package_owners.package_artifact_source
  WHERE package_owners.package_owner_artifact_namespace = 'offchainlabs'
    AND package_owners.package_owner_artifact_name = 'stylus-sdk-rs'
  )
   SELECT  p.display_name as Name,
            m.metric_name as Metric,
            ts.sample_date as Date,
            ts.amount as Value
    FROM metrics_v0 m
    JOIN timeseries_metrics_by_project_v0 ts
    on m.metric_id = ts.metric_id
    JOIN projects_v1 p
    on p.project_id = ts.project_id
    JOIN dep_projects a
    on p.project_id = a.from_project_id
    where metric_name = 'GITHUB_active_developers_monthly'
    and YEAR(ts.sample_date) in (2024, 2025)
"""

df = client.to_pandas(query)
df.to_csv('stylus_dependencies_active_dev_monthly.csv', index=False)
df
# Out:
#                  Name                            Metric        Date  Value
# 0    Fracton Research  GITHUB_active_developers_monthly  2024-01-01      1
# 1    Fracton Research  GITHUB_active_developers_monthly  2024-01-01      1
# 2      CryptoSmartNow  GITHUB_active_developers_monthly  2025-02-01      1
# 3      CryptoSmartNow  GITHUB_active_developers_monthly  2025-02-01      1
# 4      CryptoSmartNow  GITHUB_active_developers_monthly  2024-03-01      3
# ..                ...                               ...         ...    ...
# 291         LimeChain  GITHUB_active_developers_monthly  2024-05-01     15
# 292         LimeChain  GITHUB_active_developers_monthly  2024-09-01     12
# 293         LimeChain  GITHUB_active_developers_monthly  2024-09-01     12
# 294         LimeChain  GITHUB_active_developers_monthly  2024-04-01     14
# 295         LimeChain  GITHUB_active_developers_monthly  2024-04-01     14
#
# [296 rows x 4 columns]
